# %% [markdown]
# # Program 4 - Type Conversions

# %%
print(float(99) / 100)
# Out:
# 0.99

# %%
i = 42
type(i)
# Out:
# int

# %%
f = float(i)
print(f)
# Out:
# 42.0

# %%
type(f)
# Out:
# float

# %%
print(1 + 2 * float(3) / 4 - 5)
# Out:
# -2.5

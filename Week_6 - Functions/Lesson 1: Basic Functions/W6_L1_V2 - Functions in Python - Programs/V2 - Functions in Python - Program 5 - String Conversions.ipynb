# %% [markdown]
# # Program 5 - String Conversions

# %%
sval = '123'

# %%
type(sval)
# Out:
# str

# %%
print(sval + 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-844c8fe77d11> in <module>
# ----> 1 print(sval + 1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
ival = int(sval)

# %%
type(ival)
# Out:
# int

# %%
print(ival + 1)
# Out:
# 124

# %%
nsv = 'hello bob'

# %%
niv = int(nsv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-023fdb204a1b> in <module>
# ----> 1 niv = int(nsv)
#
# ValueError: invalid literal for int() with base 10: 'hello bob'
